# %%
#practice:4
# question:1 using if_else statment finding greatest number
a=int(input())
b=int(input())
c=int(input())
if a>b:
    print("a is greatest number")
elif b>c:
    print("b is greatest number")
else:
    print("c is greatest number")
# Out:
#  10
#  20
#  30
# c is greatest number

# %%
#practice:4
# question:2 using if_else statment finding second greatest number
a=int(input())
b=int(input())
c=int(input())
if a>b:
    print("a is greatest number",a)
elif c<a:
    print("c is greatest number",c)
else:
    print("b is greatest number",b)
# Out:
#  5
#  7
#  8
# b is greatest number 7

# %%
#practice:4
# question:3 using if_else statment finding smallest number
a=int(input())
b=int(input())
c=int(input())
d=int(input())
smallest=a
if b<smallest:
    smallest=b
if c<smallest:
    smallest=c
if d<smallest:
    smallest=d
print("the smallest number is:",smallest)
# Out:
#  4
#  5
#  3
#  1
# the smallest number is: 1

# %%
#practice:4
# question:4 using if_else statment finding positive or negative number
a=int(input("enter the number"))
if a>0:
    print("a is positive number")
else:
    print("a is negative number")
# Out:
# enter the number 60
# a is positive number

# %%
#practice:4
# question:5 using if_else statment finding leap year
a=int(input("enter the year"))
if a%400==0 or a%100!=0 and a%4==0:
    print(" leap year")
else:
    print("not leap year")
# Out:
# enter the year 2000
#  leap year

# %%
#practice:4
# question:6 using if_else statment finding perfect_square
import math
a=int(input("enter a number"))
sqrt_a=math.sqrt(a)
if sqrt_a.is_integer():
    print("yes")
else:
    print("no")
# Out:
# enter a number 3
# no

# %%
# question:7 using if_else statment finding vowel
a=input()
if a in 'aeiouAEIOU':
    print('vowel')
elif a.isalpha() :
    print('consonant')
else:
    print('not an alpabet')
# Out:
#  5
# not an alpabet

# %%
#using list method finding greatest number
a=int(input())
b=int(input())
c=int(input())
d=[a,b,c]
d.sort()
print("greatest number is:",d[-1])
# Out:
#  10
#  20
#  30
# greatest number is: 30

# %%
#using list method finding smallest number
a=int(input())
b=int(input())
c=int(input())
d=int(input())
e=[a,b,c,d]
e.sort()
print("smallest number is :",e[0])
# Out:
#  4
#  5
#  3
#  1
# smallest number is : 1

# %%
#practice:4
#question:8 using if_else statments  finding quadrant in graph
x=int(input())
y=int(input())
if (x>0) and (y>0):
     print("Ist Quadrant")
elif (x<0) and (y>0):
    print("IInd Quadrant")
elif (x<0) and (y<0):
    print("IIIrd Quadrant")
elif (x>0) and (y<0):
    print("IVth Quadrant")
elif x==0 and y>0:
    print("y is positive axis")
elif x==0 and y<0:
    print("y is negative axis")
elif y==0 and x>0:
    print("x is positive axis")
elif y==0 and x<0:
    print("x is negative axis")
else:
    print("origin")
# Out:
#  0
#  0
# origin
